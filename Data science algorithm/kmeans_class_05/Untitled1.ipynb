# %%
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
img = cv2.imread("./doctor-strange-2-benedict-cumberbatch.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %% [raw]
# img.show()

# %%
plt.figure(figsize=(5,5))
plt.imshow(img)
plt.show()
print(img.shape)
# Out:
# (464, 825, 3)

# %%
c_img=img.copy()

c_img=np.reshape(c_img,(-1,3))

print(c_img.shape)
# Out:
# (382800, 3)

# %%
kmeans=KMeans(n_clusters=5,random_state=2)

# %%
kmeans.fit_predict(c_img)
# Out:
# array([0, 0, 0, ..., 0, 3, 3], dtype=int32)

# %%
centers=kmeans.cluster_centers_.astype(int)

# %%
print(centers)
# Out:
# [[ 27  25  37]
#  [240 243 237]
#  [176  71  44]
#  [114 137 147]
#  [235 165 112]]

# %%
print(np.unique(kmeans.labels_,return_counts=True))
# Out:
# (array([0, 1, 2, 3, 4], dtype=int32), array([149444,  81091,  55926,  41636,  54703]))

# %%
per=np.array(np.unique(kmeans.labels_,return_counts=True)[1],dtype=np.float32)

per=per/c_img.shape[0]
print(per)
# Out:
# [0.39039707 0.21183647 0.14609718 0.10876698 0.1429023 ]

# %%
dom=[ [per[ix],centers[ix]] for ix in range(kmeans.n_clusters)]
     
DOM=sorted(dom,reverse=False)
     
print(DOM)
# Out:
# [[0.10876698014629049, array([114, 137, 147])], [0.1429022988505747, array([235, 165, 112])], [0.1460971786833856, array([176,  71,  44])], [0.21183646812957158, array([240, 243, 237])], [0.39039707419017766, array([27, 25, 37])]]
