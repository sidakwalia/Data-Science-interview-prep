# %%
dirs = os.listdir("./class_13/data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-d8eba97a2d31> in <module>
# ----> 1 dirs = os.listdir("./class_13/data")
#
# FileNotFoundError: [Errno 2] No such file or directory: './class_13/data'
