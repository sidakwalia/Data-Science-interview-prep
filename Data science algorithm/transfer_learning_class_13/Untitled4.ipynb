# %%
import matplotlib.pyplot as plt

# %%
for x in range(50):
    
    y=x/(1+e^-x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-edd3c34b3ff2> in <module>
#       2 for x in range(50):
#       3
# ----> 4     y=x/(1+e^-x)
#       5
#
# NameError: name 'e' is not defined
